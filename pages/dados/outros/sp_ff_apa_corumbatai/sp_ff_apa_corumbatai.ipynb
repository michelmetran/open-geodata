# %% [markdown]
# <br>
#
# # APA Corumbatai
#
# [![Repo](https://img.shields.io/badge/GitHub-repo-blue?logo=github&logoColor=f5f5f5)](https://github.com/open-geodata/sp_ff_apa-corumbatai)

# %%
import open_geodata as geo

# %%
db = geo.data.DB(db='sp_ff_apa_corumbatai')
db.list_data

# %%
gdf = geo.load_dataset(
    db='sp_ff_apa_corumbatai', name='geo.apa_corumbatai_limite'
)
gdf.explore()
