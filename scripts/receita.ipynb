# %% [markdown]
# <br>
#
# # Receita Federal

# %%
import os
from pathlib import Path

import numpy as np
import pandas as pd

# %%
down_path = Path(os.environ['USERPROFILE']) / 'Downloads'
list(down_path.rglob('*'))

# %%
df = pd.read_csv(
    down_path / 'K3241.K03200Y0.D50614.SOCIOCSV',
    sep=';',
    encoding='latin1',
    header=None,
    names=[
        'col0',  # 0
        'col1',  # 1
        'Nome do Sócio',  # 2
        'CPF do Sócio',  # 3
        'col4',  # 4
        'col5',  # 5
        'col6',  # 6
        'col7',  # 7
        'col8',  # 8
        'col9',  # 9
        'col10',  # 10
    ],
)
df
