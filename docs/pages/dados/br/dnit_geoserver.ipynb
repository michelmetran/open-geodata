# %% [markdown]
# # DNIT
#
# O Departamento Nacional de Infraestrutura de Transportes (DNIT) mantem um GeoServer disponível no endereço:
#
# > https://servicos.dnit.gov.br/dnitgeo/geoserver/web

# %%
import io

import geopandas as gpd
from owslib.wfs import WebFeatureService

# %%
wfs = WebFeatureService(
    #
    url='https://servicos.dnit.gov.br/dnitgeo/geoserver/ows',
    version='2.0.0',
)

# %% [markdown]
# <br>
#
# ---
#
# ## Listas _Layers_

# %%
list_layers = list(wfs.contents)
list_layers.sort()

print(f"Existem {len(list_layers)} camadas disponíveis no serviço WFS.")

# Display the first 10 layers
list_layers[0:10]
# Out:
# Existem 128 camadas disponíveis no serviço WFS.
# ['ics_geo:geo_ICS',
#  'sge_hml:CamadaView',
#  'sge_hml:vw_oaes_aprovadas',
#  'sgp:atr_2013',
#  'sgp:atr_2014',
#  'sgp:atr_2017',
#  'sgp:atr_2018',
#  'sgp:atr_2020',
#  'sgp:atr_2021',
#  'sgp:atr_2022']

# %% [markdown]
# <br>
#
# ---
#
# ## Obter _Layers_

# %%
# Obter os dados no formato GeoJSON (ou outro formato suportado)
response = wfs.getfeature(
    typename='vgeo:3faixa_de_dominio_termo_de_arrolamento',
    # bbox=(173700, 440400, 178700, 441400),
    # srsname='EPSG:28992'
    # srsname='EPSG:4326',
    srsname='EPSG:31983',
    outputFormat='application/json',
)
response

# %% [markdown]
# <br>
#
# ---
#
# ## Geopandas

# %%
gdf = gpd.read_file(filename=io.BytesIO(response.read()))
gdf.info()
gdf.head()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        63 non-null     object
#  1   LEGENDA   63 non-null     object
#  2   SENTIDO   63 non-null     object
#  3   KM        63 non-null     object
#  4   DOC_REF   63 non-null     object
#  5   DOC_NUM   63 non-null     object
#  6   ANO       63 non-null     int32
#  7   LINK      63 non-null     object
#  8   OBS       63 non-null     object
#  9   geometry  63 non-null     geometry
# dtypes: geometry(1), int32(1), object(8)
# memory usage: 4.8+ KB
#                                          id                  LEGENDA SENTIDO  \
# 0  3faixa_de_dominio_termo_de_arrolamento.1  FD Termo de arrolamento      RJ
# 1  3faixa_de_dominio_termo_de_arrolamento.2  FD Termo de arrolamento      JF
# 2  3faixa_de_dominio_termo_de_arrolamento.3  FD Termo de arrolamento       -
# 3  3faixa_de_dominio_termo_de_arrolamento.4  FD Termo de arrolamento       -
# 4  3faixa_de_dominio_termo_de_arrolamento.5  FD Termo de arrolamento      JF
#
#           KM                                       DOC_REF DOC_NUM  ANO  \
# 0        125  Tabela de Largura da Faixa de Domínio - DNIT       -    0
# 1        125  Tabela de Largura da Faixa de Domínio - DNIT       -    0
# 2          -                                             -       -    0
# 3          -                                             -       -    0
# 4  102 - 103  Tabela de Largura da Faixa de Domínio - DNIT       -    0
#
#                                                 LINK OBS  \
# 0  Documentos\01_Entrega_Baixada_Serra\Baixada\Fa...   -
# 1  \01_Entrega_Baixada_Serra\Baixada\Faixa de Dom...   -
# 2                                                  -   -
# 3                                                  -   -
# 4  \01_Entrega_Baixada_Serra\Baixada\Faixa de Dom...   -
#
#                                             geometry
# 0  MULTILINESTRING ((675594.363 7475814.833, 6756...
# 1  MULTILINESTRING ((675824.06 7475751.894, 67581...
# 2  MULTILINESTRING ((675742.53 7476096.747, 67574...
# 3  MULTILINESTRING ((675742.662 7476096.879, 6757...
# 4  MULTILINESTRING ((676188.948 7496642.394, 6761...

# %%
gdf.crs
# Out:
# <Projected CRS: EPSG:31983>
# Name: SIRGAS 2000 / UTM zone 23S
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Brazil - between 48°W and 42°W, northern and southern hemispheres, onshore and offshore.
# - bounds: (-48.0, -33.5, -42.0, 5.13)
# Coordinate Operation:
# - name: UTM zone 23S
# - method: Transverse Mercator
# Datum: Sistema de Referencia Geocentrico para las AmericaS 2000
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42c00de61d4065358543d3bf9a964cb8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42c00de61d4065358543d3bf9a964cb8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42c00de61d4065358543d3bf9a964cb8 = L.map(
#                 &quot;map_42c00de61d4065358543d3bf9a964cb8&quot;,
#                 {
#                     center: [-22.66757136617499, -43.248156127499776],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_42c00de61d4065358543d3bf9a964cb8);
#
#
#
#
#
#             var tile_layer_a95712f54796c1bbb3bedfea99be7c48 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a95712f54796c1bbb3bedfea99be7c48.addTo(map_42c00de61d4065358543d3bf9a964cb8);
#
#
#             map_42c00de61d4065358543d3bf9a964cb8.fitBounds(
#                 [[-22.816698353630844, -43.29276968799981], [-22.51844437871913, -43.203542566999744]],
#                 {}
#             );
#
#
#         function geo_json_31113e5838535333ad62912ad36e99a2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_31113e5838535333ad62912ad36e99a2_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_31113e5838535333ad62912ad36e99a2_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_31113e5838535333ad62912ad36e99a2_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_31113e5838535333ad62912ad36e99a2_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_31113e5838535333ad62912ad36e99a2.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_31113e5838535333ad62912ad36e99a2_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_31113e5838535333ad62912ad36e99a2 = L.geoJson(null, {
#                 onEachFeature: geo_json_31113e5838535333ad62912ad36e99a2_onEachFeature,
#
#                 style: geo_json_31113e5838535333ad62912ad36e99a2_styler,
#                 pointToLayer: geo_json_31113e5838535333ad62912ad36e99a2_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_31113e5838535333ad62912ad36e99a2_add (data) {
#             geo_json_31113e5838535333ad62912ad36e99a2
#                 .addData(data);
#         }
#             geo_json_31113e5838535333ad62912ad36e99a2_add({&quot;bbox&quot;: [-43.29276968799981, -22.816698353630844, -43.203542566999744, -22.51844437871913], &quot;features&quot;: [{&quot;bbox&quot;: [-43.28942104630426, -22.816154078892172, -43.287841870048304, -22.813634988854197], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-43.28906306881605, -22.816154078892172], [-43.28880840564246, -22.815700940510567], [-43.28849349436718, -22.81516456679029], [-43.28828595966414, -22.
