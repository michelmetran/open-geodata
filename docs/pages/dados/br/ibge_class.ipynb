# %% [markdown]
# <br>
#
# # IBGE
#
# O [**GeoFTP do IBGE**](http://geoftp.ibge.gov.br/) é o servidor do [**Instituto Brasileiro de Geografia e Estatistica (IBGE)**](https://www.infraestruturameioambiente.sp.gov.br) que disponibiliza diversas informações relevantes, majoritariamente em formato _shapefile_, ou seja, em formato editável, sendo que os dados armazenados nesse repositório são derivados destes.

# %%
import tempfile
from pathlib import Path

import open_geodata as geo

# %% [markdown]
# <br>
#
# ----
#
# ## Obtem Dados

# %%
# Instancia classe IBGE
ibge = geo.br.ibge.geoftp.IBGE()

# Obtem Malhas de 2018
gdf = ibge.get_malhas_municipais(estado='SP')

# Resultados
gdf.info()
gdf.head()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 645 entries, 0 to 644
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_municipio    645 non-null    int64
#  1   nome_municipio  645 non-null    object
#  2   geometry        645 non-null    geometry
# dtypes: geometry(1), int64(1), object(1)
# memory usage: 15.2+ KB
#    id_municipio  nome_municipio  \
# 0       3517208        GUAIÇARA
# 1       3504206       AURIFLAMA
# 2       3520905         IPAUSSU
# 3       3519071     HORTOLÂNDIA
# 4       3505401  BARRA DO TURVO
#
#                                             geometry
# 0  POLYGON ((-49.82514 -21.58632, -49.82509 -21.5...
# 1  POLYGON ((-50.61899 -20.66481, -50.61869 -20.6...
# 2  POLYGON ((-49.67444 -23.05396, -49.67364 -23.0...
# 3  POLYGON ((-47.24001 -22.84656, -47.24036 -22.8...
# 4  POLYGON ((-48.50267 -24.74675, -48.50245 -24.7...

# %% [markdown]
# <br>
#
# ----
#
# ## Filtrando

# %%
gdf = gdf.loc[gdf['nome_municipio'] == 'SANTOS']
gdf
# Out:
#      id_municipio nome_municipio  \
# 559       3548500         SANTOS
#
#                                               geometry
# 559  MULTIPOLYGON (((-46.16306 -24.32988, -46.16265...

# %% [markdown]
# <br>
#
# -----
#
# ## Datuns

# %%
# Reprojeta
print(gdf.crs)
gdf = gdf.to_crs(epsg=4326)
print(gdf.crs)
# Out:
# EPSG:4674
# EPSG:4326

# %% [markdown]
# <br>
#
#
# -----
#
# ## Explorando

# %%
gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abda1609a30bdac3dcfe0e2b6617b880 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abda1609a30bdac3dcfe0e2b6617b880&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abda1609a30bdac3dcfe0e2b6617b880 = L.map(
#                 &quot;map_abda1609a30bdac3dcfe0e2b6617b880&quot;,
#                 {
#                     center: [-24.03328483349995, -46.28180886249996],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_abda1609a30bdac3dcfe0e2b6617b880);
#
#
#
#
#
#             var tile_layer_9668c5c10a716e062a0b39d2c8960940 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9668c5c10a716e062a0b39d2c8960940.addTo(map_abda1609a30bdac3dcfe0e2b6617b880);
#
#
#             map_abda1609a30bdac3dcfe0e2b6617b880.fitBounds(
#                 [[-24.331318667999938, -46.403066999999965], [-23.73525099899996, -46.16055072499995]],
#                 {}
#             );
#
#
#         function geo_json_b2666c0c4e83739dfd47bd9c065091d9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b2666c0c4e83739dfd47bd9c065091d9_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b2666c0c4e83739dfd47bd9c065091d9_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_b2666c0c4e83739dfd47bd9c065091d9_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b2666c0c4e83739dfd47bd9c065091d9_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_b2666c0c4e83739dfd47bd9c065091d9.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b2666c0c4e83739dfd47bd9c065091d9_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b2666c0c4e83739dfd47bd9c065091d9 = L.geoJson(null, {
#                 onEachFeature: geo_json_b2666c0c4e83739dfd47bd9c065091d9_onEachFeature,
#
#                 style: geo_json_b2666c0c4e83739dfd47bd9c065091d9_styler,
#                 pointToLayer: geo_json_b2666c0c4e83739dfd47bd9c065091d9_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_b2666c0c4e83739dfd47bd9c065091d9_add (data) {
#             geo_json_b2666c0c4e83739dfd47bd9c065091d9
#                 .addData(data);
#         }
#             geo_json_b2666c0c4e83739dfd47bd9c065091d9_add({&quot;bbox&quot;: [-46.403066999999965, -24.331318667999938, -46.16055072499995, -23.73525099899996], &quot;features&quot;: [{&quot;bbox&quot;: [-46.403066999999965, -24.331318667999938, -46.16055072499995, -23.73525099899996], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-46.163058012999954, -24.32988142199997], [-46.16265365999993, -24.329218025999978], [-46.16216840699997, -24.328665177999937], [-46.16176405099998, -24.

# %% [markdown]
# <br>
#
# -----
#
# ## Salvando
#
# Em uma pasta temporária

# %%
# Salva
with tempfile.TemporaryDirectory() as temp_dir:
    # Cria o caminho temporário em formato Path
    temp_path = Path(temp_dir)

    # Salva em GeoJSON e GPKG
    gdf.to_file(
        temp_path / 'limite_municipal_sp.geojson',
        driver='GeoJSON',
        encoding='utf-8',
    )
    gdf.to_file(
        temp_path / 'limite_municipal_sp.gpkg',
        layer='Limite',
        driver='GPKG',
    )

# %% [markdown]
# <br>
#
#
# ----
#
# ## *Download*
#
# Faz o *download* do arquivo bruto

# %%
with tempfile.TemporaryDirectory() as temp_dir:
    # Cria o caminho temporário em formato Path
    temp_path = Path(temp_dir)

    # Faz o download para o caminho desejado
    ibge.download_malhas_municipais(output_path=temp_path)

    # Aponta o arquivo
    print(list(temp_path.glob('*')))
